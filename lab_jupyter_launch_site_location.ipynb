# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Hands-on Lab: Interactive Visual Analytics with Folium**

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# The launch success rate may depend on many factors such as payload mass, orbit type, and so on. It may also depend on the location and proximities of a launch site, i.e., the initial position of rocket trajectories. Finding an optimal location for building a launch site certainly involves many factors and hopefully we could discover some of the factors by analyzing the existing launch site locations.

# %% [markdown]
# In the previous exploratory data analysis labs, you have visualized the SpaceX launch dataset using `matplotlib` and `seaborn` and discovered some preliminary correlations between the launch site and success rates. In this lab, you will be performing more interactive visual analytics using `Folium`.

# %% [markdown]
# ## Objectives

# %% [markdown]
# This lab contains the following tasks:
#
# *   **TASK 1:** Mark all launch sites on a map
# *   **TASK 2:** Mark the success/failed launches for each site on the map
# *   **TASK 3:** Calculate the distances between a launch site to its proximities
#
# After completed the above tasks, you should be able to find some geographical patterns about launch sites.

# %% [markdown]
# Let's first import required Python packages for this lab:

# %%
import piplite
await piplite.install(['folium'])
await piplite.install(['pandas'])

# %%
import folium
import pandas as pd

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %%
import pandas as pd

# Descargar y leer el archivo CSV
from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
resp = await fetch(URL)
spacex_csv_file = io.BytesIO((await resp.arrayBuffer()).to_py())
spacex_df = pd.read_csv(spacex_csv_file)

# Verificar que los datos han sido cargados correctamente
print(spacex_df.head())

# Agrupar datos por sitio de lanzamiento y seleccionar columnas relevantes
launch_sites_df = spacex_df.groupby('Launch Site', as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]

# Verificar los datos procesados
print(launch_sites_df.head())
# Out:
#    Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 0              1  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1              2  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2              3  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3              4  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4              5  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  Payload Mass (kg)  \
# 0               Dragon Spacecraft Qualification Unit                0.0
# 1  Dragon demo flight C1, two CubeSats,  barrel o...                0.0
# 2                             Dragon demo flight C2+              525.0
# 3                                       SpaceX CRS-1              500.0
# 4                                       SpaceX CRS-2              677.0
#
#        Orbit         Customer        Landing Outcome  class        Lat  \
# 0        LEO           SpaceX  Failure   (parachute)      0  28.562302
# 1  LEO (ISS)  NASA (COTS) NRO  Failure   (parachute)      0  28.562302
# 2  LEO (ISS)      NASA (COTS)             No attempt      0  28.562302
# 3  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
# 4  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
#
#         Long
# 0 -80.577356
# 1 -80.577356
# 2 -80.577356
# 3 -80.577356
# 4 -80.577356
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %% [markdown]
# If you need to refresh your memory about folium, you may download and refer to this previous folium lab:

# %% [markdown]
# [Generating Maps with Python](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/v4/DV0101EN-Exercise-Generating-Maps-in-Python.ipynb)

# %%
## Task 1: Mark all launch sites on a map
import folium
import pandas as pd

# Descargar y leer el archivo CSV
from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
resp = await fetch(URL)
spacex_csv_file = io.BytesIO((await resp.arrayBuffer()).to_py())
spacex_df = pd.read_csv(spacex_csv_file)

# Verificar que los datos han sido cargados correctamente
print(spacex_df.head())

# Agrupar datos por sitio de lanzamiento y seleccionar columnas relevantes
launch_sites_df = spacex_df.groupby('Launch Site', as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]

# Verificar los datos procesados
print(launch_sites_df.head())

# Crear un mapa centrado en el promedio de las ubicaciones de los sitios de lanzamiento
map_center = [launch_sites_df['Lat'].mean(), launch_sites_df['Long'].mean()]
site_map = folium.Map(location=map_center, zoom_start=5)

# Añadir marcadores para cada sitio de lanzamiento
for _, row in launch_sites_df.iterrows():
    folium.Marker(
        location=[row['Lat'], row['Long']],
        popup=row['Launch Site'],
        icon=folium.Icon(icon="rocket", color="blue")
    ).add_to(site_map)

# Guardar y mostrar el mapa correctamente en Jupyter Notebook
site_map
# Out:
#    Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 0              1  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1              2  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2              3  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3              4  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4              5  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  Payload Mass (kg)  \
# 0               Dragon Spacecraft Qualification Unit                0.0
# 1  Dragon demo flight C1, two CubeSats,  barrel o...                0.0
# 2                             Dragon demo flight C2+              525.0
# 3                                       SpaceX CRS-1              500.0
# 4                                       SpaceX CRS-2              677.0
#
#        Orbit         Customer        Landing Outcome  class        Lat  \
# 0        LEO           SpaceX  Failure   (parachute)      0  28.562302
# 1  LEO (ISS)  NASA (COTS) NRO  Failure   (parachute)      0  28.562302
# 2  LEO (ISS)      NASA (COTS)             No attempt      0  28.562302
# 3  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
# 4  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
#
#         Long
# 0 -80.577356
# 1 -80.577356
# 2 -80.577356
# 3 -80.577356
# 4 -80.577356
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fc296e649c92e7a3221df0e0586687c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fc296e649c92e7a3221df0e0586687c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fc296e649c92e7a3221df0e0586687c = L.map(
#                 &quot;map_9fc296e649c92e7a3221df0e0586687c&quot;,
#                 {
#                     center: [30.08289697, -90.602954325],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ff7da37cd2f6418d63e2ee6887b9418 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ff7da37cd2f6418d63e2ee6887b9418.addTo(map_9fc296e649c92e7a3221df0e0586687c);
#
#
#             var marker_2f5451e97ec17ae4257f38f7876b5aa9 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_9fc296e649c92e7a3221df0e0586687c);
#
#
#             var icon_3e52e510ac4ffe0ad851fe525302dc28 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d656af47145da76ad92ad0ef17efcd4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba4223ff6ac8fcc8426ae47824d2140a = $(`&lt;div id=&quot;html_ba4223ff6ac8fcc8426ae47824d2140a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_d656af47145da76ad92ad0ef17efcd4e.setContent(html_ba4223ff6ac8fcc8426ae47824d2140a);
#
#
#
#         marker_2f5451e97ec17ae4257f38f7876b5aa9.bindPopup(popup_d656af47145da76ad92ad0ef17efcd4e)
#         ;
#
#
#
#
#                 marker_2f5451e97ec17ae4257f38f7876b5aa9.setIcon(icon_3e52e510ac4ffe0ad851fe525302dc28);
#
#
#             var marker_39fce808037076a5f4889a61c4689f50 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {
# }
#             ).addTo(map_9fc296e649c92e7a3221df0e0586687c);
#
#
#             var icon_846aabafc0b2e95ade324d05ef61c4db = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_de9ce403f98855fc56a5be71dbd7d2d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d003b2c968c44c1747c9015840d760eb = $(`&lt;div id=&quot;html_d003b2c968c44c1747c9015840d760eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#                 popup_de9ce403f98855fc56a5be71dbd7d2d4.setContent(html_d003b2c968c44c1747c9015840d760eb);
#
#
#
#         marker_39fce808037076a5f4889a61c4689f50.bindPopup(popup_de9ce403f98855fc56a5be71dbd7d2d4)
#         ;
#
#
#
#
#                 marker_39fce808037076a5f4889a61c4689f50.setIcon(icon_846aabafc0b2e95ade324d05ef61c4db);
#
#
#             var marker_dbc0f306e54389260bdffab270dc30ce = L.marker(
#                 [28.57325457, -80.64689529],
#                 {
# }
#             ).addTo(map_9fc296e649c92e7a3221df0e0586687c);
#
#
#             var icon_9bbd761b03f01c4dfff04754184f8270 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_12958b032aceb65d9e05d757541e0aac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb3fdcee8b211c6f9ca4ebaafc1d11b6 = $(`&lt;div id=&quot;html_eb3fdcee8b211c6f9ca4ebaafc1d11b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC-39A&lt;/div&gt;`)[0];
#                 popup_12958b032aceb65d9e05d757541e0aac.setContent(html_eb3fdcee8b211c6f9ca4ebaafc1d11b6);
#
#
#
#         marker_dbc0f306e54389260bdffab270dc30ce.bindPopup(popup_12958b032aceb65d9e05d757541e0aac)
#         ;
#
#
#
#
#                 marker_dbc0f306e54389260bdffab270dc30ce.setIcon(icon_9bbd761b03f01c4dfff04754184f8270);
#
#
#             var marker_5fbcec7eec57d5c3

# %% [markdown]
# First, let's try to add each site's location on a map using site's latitude and longitude coordinates

# %% [markdown]
# The following dataset with the name `spacex_launch_geo.csv` is an augmented dataset with latitude and longitude added for each site.

# %%
# Download and read the `spacex_launch_geo.csv`
from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
resp = await fetch(URL)
spacex_csv_file = io.BytesIO((await resp.arrayBuffer()).to_py())
spacex_df=pd.read_csv(spacex_csv_file)
print(spacex_df.head())  # Ver los primeros registros del DataFrame
# Out:
#    Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 0              1  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1              2  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2              3  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3              4  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4              5  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  Payload Mass (kg)  \
# 0               Dragon Spacecraft Qualification Unit                0.0
# 1  Dragon demo flight C1, two CubeSats,  barrel o...                0.0
# 2                             Dragon demo flight C2+              525.0
# 3                                       SpaceX CRS-1              500.0
# 4                                       SpaceX CRS-2              677.0
#
#        Orbit         Customer        Landing Outcome  class        Lat  \
# 0        LEO           SpaceX  Failure   (parachute)      0  28.562302
# 1  LEO (ISS)  NASA (COTS) NRO  Failure   (parachute)      0  28.562302
# 2  LEO (ISS)      NASA (COTS)             No attempt      0  28.562302
# 3  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
# 4  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
#
#         Long
# 0 -80.577356
# 1 -80.577356
# 2 -80.577356
# 3 -80.577356
# 4 -80.577356

# %% [markdown]
# Now, you can take a look at what are the coordinates for each site.

# %%
# Select relevant sub-columns: `Launch Site`, `Lat(Latitude)`, `Long(Longitude)`, `class`
spacex_df = spacex_df[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %% [markdown]
# Above coordinates are just plain numbers that can not give you any intuitive insights about where are those launch sites. If you are very good at geography, you can interpret those numbers directly in your mind. If not, that's fine too. Let's visualize those locations by pinning them on a map.

# %% [markdown]
# We first need to create a folium `Map` object, with an initial center location to be NASA Johnson Space Center at Houston, Texas.

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %% [markdown]
# We could use `folium.Circle` to add a highlighted circle area with a text label on a specific coordinate. For example,

# %%
import folium
from folium.features import DivIcon

# Coordenada del NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]

# Crear el mapa centrado en NASA JSC
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# Crear un círculo resaltado con etiqueta emergente
circle = folium.Circle(
    location=nasa_coordinate,
    radius=1000,  # Radio en metros
    color='#d35400',
    fill=True,
    fill_color='#d35400'
).add_child(folium.Popup('NASA Johnson Space Center'))

# Crear un marcador con texto rojo para el sitio
marker = folium.map.Marker(
    location=nasa_coordinate,
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 14px; font-weight: bold; color:#d35400;"><b>NASA JSC</b></div>'
    )
)

# Agregar elementos al mapa
circle.add_to(site_map)
marker.add_to(site_map)

# Mostrar el mapa en Jupyter Notebook
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_202d27d5ed27a33349e8c083e9fd0494 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_202d27d5ed27a33349e8c083e9fd0494&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_202d27d5ed27a33349e8c083e9fd0494 = L.map(
#                 &quot;map_202d27d5ed27a33349e8c083e9fd0494&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9041104cdebb2c59649e44809a731f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c9041104cdebb2c59649e44809a731f5.addTo(map_202d27d5ed27a33349e8c083e9fd0494);
#
#
#             var circle_0bd207be0d24f885d044c6574d09cd7a = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_202d27d5ed27a33349e8c083e9fd0494);
#
#
#         var popup_ee2148f600b4e658bfc6a32f49cdf273 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92452d22debec2a79fb819f8d0e757b1 = $(`&lt;div id=&quot;html_92452d22debec2a79fb819f8d0e757b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_ee2148f600b4e658bfc6a32f49cdf273.setContent(html_92452d22debec2a79fb819f8d0e757b1);
#
#
#
#         circle_0bd207be0d24f885d044c6574d09cd7a.bindPopup(popup_ee2148f600b4e658bfc6a32f49cdf273)
#         ;
#
#
#
#
#             var marker_71eda6255516d1c360456f0879bbb591 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_202d27d5ed27a33349e8c083e9fd0494);
#
#
#             var div_icon_934dea9a56e5a0760c972b1808bfb572 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 14px; font-weight: bold; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_71eda6255516d1c360456f0879bbb591.setIcon(div_icon_934dea9a56e5a0760c972b1808bfb572);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# and you should find a small yellow circle near the city of Houston and you can zoom-in to see a larger circle.

# %% [markdown]
# Now, let's add a circle for each launch site in data frame `launch_sites`

# %% [markdown]
# *TODO:*  Create and add `folium.Circle` and `folium.Marker` for each launch site on the site map

# %% [markdown]
# An example of folium.Circle:

# %% [markdown]
# `folium.Circle(coordinate, radius=1000, color='#000000', fill=True).add_child(folium.Popup(...))`

# %% [markdown]
# An example of folium.Marker:

# %% [markdown]
# `folium.map.Marker(coordinate, icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0), html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'label', ))`

# %%
# Si estás en Jupyter Lite, instala paquetes con piplite
import piplite
await piplite.install(['folium', 'pandas'])

# Importar bibliotecas necesarias
import folium
import pandas as pd
from folium.features import DivIcon
from js import fetch
import io

# Descargar y leer el archivo CSV con coordenadas de los sitios de lanzamiento
URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
resp = await fetch(URL)
spacex_csv_file = io.BytesIO((await resp.arrayBuffer()).to_py())
spacex_df = pd.read_csv(spacex_csv_file)

# Filtrar columnas necesarias y eliminar duplicados
launch_sites_df = spacex_df[['Launch Site', 'Lat', 'Long']].drop_duplicates()

# Inicializar el mapa centrado en el promedio de las ubicaciones de los sitios de lanzamiento
map_center = [launch_sites_df['Lat'].mean(), launch_sites_df['Long'].mean()]
site_map = folium.Map(location=map_center, zoom_start=5)

# Agregar círculos y marcadores para cada sitio de lanzamiento
for _, row in launch_sites_df.iterrows():
    folium.Circle(
        location=[row['Lat'], row['Long']],
        radius=1000,
        color='blue',
        fill=True,
        fill_color='blue'
    ).add_child(folium.Popup(row['Launch Site'])).add_to(site_map)

    folium.map.Marker(
        location=[row['Lat'], row['Long']],
        icon=DivIcon(
            icon_size=(20,20),
            icon_anchor=(0,0),
            html='<div style="font-size: 12px; color:red;"><b>%s</b></div>' % row['Launch Site'],
        )
    ).add_to(site_map)

# Mostrar el mapa en Jupyter Notebook
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_53631f64978bb98d69ba0ead864d60f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_53631f64978bb98d69ba0ead864d60f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_53631f64978bb98d69ba0ead864d60f1 = L.map(
#                 &quot;map_53631f64978bb98d69ba0ead864d60f1&quot;,
#                 {
#                     center: [30.08289697, -90.60295432500001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b41318543de19fef939b1eaaacca79d2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b41318543de19fef939b1eaaacca79d2.addTo(map_53631f64978bb98d69ba0ead864d60f1);
#
#
#             var circle_a5ece9d11adccc392f8a017ebbde9a3b = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_53631f64978bb98d69ba0ead864d60f1);
#
#
#         var popup_740bc8890be6737a9e0ec4a462924f40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b77888181d53f05fd8d0e53221c1a80 = $(`&lt;div id=&quot;html_7b77888181d53f05fd8d0e53221c1a80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_740bc8890be6737a9e0ec4a462924f40.setContent(html_7b77888181d53f05fd8d0e53221c1a80);
#
#
#
#         circle_a5ece9d11adccc392f8a017ebbde9a3b.bindPopup(popup_740bc8890be6737a9e0ec4a462924f40)
#         ;
#
#
#
#
#             var marker_4c5d0ac5969f784087efd8a4ab41151d = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_53631f64978bb98d69ba0ead864d60f1);
#
#
#             var div_icon_5340520f71e3a43aece1be87959a895e = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:red;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_4c5d0ac5969f784087efd8a4ab41151d.setIcon(div_icon_5340520f71e3a43aece1be87959a895e);
#
#
#             var circle_dde5acc0d19e75cbc08f6538c6351b75 = L.circle(
#                 [34.63283416, -120.6107455],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_53631f64978bb98d69ba0ead864d60f1);
#
#
#         var popup_5cf7e8b69bde7b3ba710b0bdb0b09335 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb88779d9402aaa09f28749a72066b8a = $(`&lt;div id=&quot;html_eb88779d9402aaa09f28749a72066b8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC-4E&lt;/div&gt;`)[0];
#                 popup_5cf7e8b69bde7b3ba710b0bdb0b09335.setContent(html_eb88779d9402aaa09f28749a72066b8a);
#
#
#
#         circle_dde5acc0d19e75cbc08f6538c6351b75.bindPopup(popup_5cf7e8b69bde7b3ba710b0bdb0b09335)
#         ;
#
#
#
#
#             var marker_935c8f53f275b35ea56c16cf5b98f0ba = L.marker(
#                 [34.63283416, -120.6107455],
#                 {
# }
#             ).addTo(map_53631f64978bb98d69ba0ead864d60f1);
#
#
#             var div_icon_4f159a8dc87dd8826a4417f4099a13e1 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:red;\&quot;\u003e\u003cb\u003eVAFB SLC-4E\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_935c8f53f275b35ea56c16cf5b98f0ba.setIcon(div_icon_4f159a8dc87dd8826a4417f4099a13e1);

# %% [markdown]
# The generated map with marked launch sites should look similar to the following:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_markers.png">
# </center>

# %% [markdown]
# Now, you can explore the map by zoom-in/out the marked areas
# , and try to answer the following questions:
#
# *   Are all launch sites in proximity to the Equator line?
# *   Are all launch sites in very close proximity to the coast?
#
# Also please try to explain your findings.

# %%
# Agregar círculos y marcadores para cada sitio de lanzamiento
for _, row in launch_sites_df.iterrows():
    folium.Circle(
        location=[row['Lat'], row['Long']],
        radius=1000,
        color='blue',
        fill=True,
        fill_color='blue'
    ).add_child(folium.Popup(row['Launch Site'])).add_to(site_map)

    folium.map.Marker(
        location=[row['Lat'], row['Long']],
        icon=DivIcon(
            icon_size=(20,20),
            icon_anchor=(0,0),
            html='<div style="font-size: 12px; color:blue;"><b>%s</b></div>' % row['Launch Site'],
        )
    ).add_to(site_map)

# Agregar marcadores de éxito y fallo en los lanzamientos
for _, row in spacex_df.iterrows():
    color = "green" if row["class"] == 1 else "red"  # Verde para éxito, rojo para fallo
    folium.Circle(
        location=[row["Lat"], row["Long"]],
        radius=500,
        color=color,
        fill=True,
        fill_color=color
    ).add_child(folium.Popup(f"Lanzamiento en {row['Launch Site']} - {'Éxito' if row['class'] == 1 else 'Fallo'}")).add_to(site_map)

# Mostrar el mapa en Jupyter Notebook
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b94cb1fc45ec4bdc4ed02a42be03a0b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b94cb1fc45ec4bdc4ed02a42be03a0b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b94cb1fc45ec4bdc4ed02a42be03a0b3 = L.map(
#                 &quot;map_b94cb1fc45ec4bdc4ed02a42be03a0b3&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b57fbb41fd3088ba50ed08ed44a89b2b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b57fbb41fd3088ba50ed08ed44a89b2b.addTo(map_b94cb1fc45ec4bdc4ed02a42be03a0b3);
#
#
#             var circle_dcdb8dbd9c4982d2079df24796ab409a = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b94cb1fc45ec4bdc4ed02a42be03a0b3);
#
#
#         var popup_0c846e5829b4af480717ca17f959b25a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e01914b57af681f6ee3dd825ab5756c8 = $(`&lt;div id=&quot;html_e01914b57af681f6ee3dd825ab5756c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_0c846e5829b4af480717ca17f959b25a.setContent(html_e01914b57af681f6ee3dd825ab5756c8);
#
#
#
#         circle_dcdb8dbd9c4982d2079df24796ab409a.bindPopup(popup_0c846e5829b4af480717ca17f959b25a)
#         ;
#
#
#
#
#             var marker_7730cf328c4d1dd2ff27eccbed296d67 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_b94cb1fc45ec4bdc4ed02a42be03a0b3);
#
#
#             var div_icon_409c866ebe4ab525a152118cc13604c5 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:yellow;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_7730cf328c4d1dd2ff27eccbed296d67.setIcon(div_icon_409c866ebe4ab525a152118cc13604c5);
#
#
#             var circle_95054ec1e0b85228c64c6c1738ff679f = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b94cb1fc45ec4bdc4ed02a42be03a0b3);
#
#
#         var popup_5e0031190b0fa92975c72798e6fe7409 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3fda55905158e5bb742b15220b80fc6 = $(`&lt;div id=&quot;html_b3fda55905158e5bb742b15220b80fc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_5e0031190b0fa92975c72798e6fe7409.setContent(html_b3fda55905158e5bb742b15220b80fc6);
#
#
#
#         circle_95054ec1e0b85228c64c6c1738ff679f.bindPopup(popup_5e0031190b0fa92975c72798e6fe7409)
#         ;
#
#
#
#
#             var marker_a7fac933015089feb3aee1c3e99f2c10 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_b94cb1fc45ec4bdc4ed02a42be03a0b3);
#
#
#             var div_icon_1f8e730e60472c83dda32e99c0edbb8c = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:blue;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_a7fac933015089feb3aee1c3e99f2c10.setIcon(div_i

# %% [markdown]
# Next, let's try to enhance the map by adding the launch outcomes for each site, and see which sites have high success rates.
# Recall that data frame spacex_df has detailed launch records, and the `class` column indicates if this launch was successful or not

# %%
spacex_df.tail(10)
# Out:
#     Flight Number        Date Time (UTC) Booster Version   Launch Site  \
# 46             43  2017-10-11   22:53:00  F9 FT  B1031.2    KSC LC-39A
# 47             44  2017-10-30   19:34:00   F9 B4 B1042.1    KSC LC-39A
# 48             54  2018-05-11   20:14:00  F9 B5  B1046.1    KSC LC-39A
# 49             45  2017-12-15   15:36:00  F9 FT  B1035.2  CCAFS SLC-40
# 50             47  2018-01-08    1:00:00   F9 B4 B1043.1  CCAFS SLC-40
# 51             48  2018-01-31   21:25:00  F9 FT  B1032.2  CCAFS SLC-40
# 52             50  2018-03-06    5:33:00     F9 B4 B1044  CCAFS SLC-40
# 53             52  2018-04-02   20:30:00  F9 B4  B1039.2  CCAFS SLC-40
# 54             53  2018-04-18   22:51:00   F9 B4 B1045.1  CCAFS SLC-40
# 55             56  2018-06-04    4:45:00  F9 B4  B1040.2  CCAFS SLC-40
#
#                                          Payload  Payload Mass (kg)  \
# 46                         SES-11 / EchoStar 105            5200.00
# 47                                   Koreasat 5A            3500.00
# 48                                 Bangabandhu-1            3600.00
# 49                                 SpaceX CRS-13            2205.00
# 50                                          Zuma            3696.65
# 51                             GovSat-1 / SES-16            4230.00
# 52                        Hispasat 30W-6  PODSat            6092.00
# 53                                 SpaceX CRS-14            2647.00
# 54  Transiting Exoplanet Survey Satellite (TESS)             362.00
# 55                                        SES-12            5384.00
#
#         Orbit             Customer       Landing Outcome  class        Lat  \
# 46        GTO         SES EchoStar  Success (drone ship)      1  28.573255
# 47        GTO       KT Corporation  Success (drone ship)      1  28.573255
# 48        GTO   Thales-Alenia/BTRC  Success (drone ship)      1  28.573255
# 49  LEO (ISS)           NASA (CRS)  Success (ground pad)      1  28.563197
# 50        LEO     Northrop Grumman  Success (ground pad)      1  28.563197
# 51        GTO                  SES    Controlled (ocean)      0  28.563197
# 52        GTO  Hispasat  NovaWurks            No attempt      0  28.563197
# 53  LEO (ISS)           NASA (CRS)            No attempt      0  28.563197
# 54        HEO           NASA (LSP)  Success (drone ship)      1  28.563197
# 55        GTO                  SES            No attempt      0  28.563197
#
#          Long
# 46 -80.646895
# 47 -80.646895
# 48 -80.646895
# 49 -80.576820
# 50 -80.576820
# 51 -80.576820
# 52 -80.576820
# 53 -80.576820
# 54 -80.576820
# 55 -80.576820

# %% [markdown]
# Next, let's create markers for all launch records.
# If a launch was successful `(class=1)`, then we use a green marker and if a launch was failed, we use a red marker `(class=0)`

# %% [markdown]
# Note that a launch only happens in one of the four launch sites, which means many launch records will have the exact same coordinate. Marker clusters can be a good way to simplify a map containing many markers having the same coordinate.

# %% [markdown]
# Let's first create a `MarkerCluster` object

# %%
from folium.plugins import MarkerCluster

# Crear el mapa centrado en el promedio de las ubicaciones de los sitios de lanzamiento
map_center = [launch_sites_df['Lat'].mean(), launch_sites_df['Long'].mean()]
site_map = folium.Map(location=map_center, zoom_start=5)

# Crear el objeto MarkerCluster y agregarlo al mapa
marker_cluster = MarkerCluster().add_to(site_map)

# Agregar marcadores de lanzamiento agrupados
for _, row in spacex_df.iterrows():
    color = "green" if row["class"] == 1 else "red"  # Verde para éxito, rojo para fallo
    
    folium.Marker(
        location=[row["Lat"], row["Long"]],
        popup=f"Lanzamiento en {row['Launch Site']} - {'Éxito' if row['class'] == 1 else 'Fallo'}",
        icon=folium.Icon(color=color, icon="rocket")  # Usamos un ícono de cohete para diferenciar los lanzamientos
    ).add_to(marker_cluster)

# Mostrar el mapa en Jupyter Notebook
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c4d51e8771d66c01ebbcffe1fca9191 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c4d51e8771d66c01ebbcffe1fca9191&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c4d51e8771d66c01ebbcffe1fca9191 = L.map(
#                 &quot;map_7c4d51e8771d66c01ebbcffe1fca9191&quot;,
#                 {
#                     center: [30.08289697, -90.60295432500001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18b84be80501b43a9349cb4e471e4367 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_18b84be80501b43a9349cb4e471e4367.addTo(map_7c4d51e8771d66c01ebbcffe1fca9191);
#
#
#             var marker_cluster_c5f64fcf8cd99d5fdf7227af11e20e24 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_d39d69823451ebc2007c5c51540940e6 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_c5f64fcf8cd99d5fdf7227af11e20e24);
#
#
#             var icon_b9525585283c1abceed6215408bc5d81 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4d228b822422369157ae6492466bef64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b303f3e1b56b4a773d7c9462c5ad78b = $(`&lt;div id=&quot;html_7b303f3e1b56b4a773d7c9462c5ad78b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lanzamiento en CCAFS LC-40 - Fallo&lt;/div&gt;`)[0];
#                 popup_4d228b822422369157ae6492466bef64.setContent(html_7b303f3e1b56b4a773d7c9462c5ad78b);
#
#
#
#         marker_d39d69823451ebc2007c5c51540940e6.bindPopup(popup_4d228b822422369157ae6492466bef64)
#         ;
#
#
#
#
#                 marker_d39d69823451ebc2007c5c51540940e6.setIcon(icon_b9525585283c1abceed6215408bc5d81);
#
#
#             var marker_0f8dde455efc236003e0157744c3ed51 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_c5f64fcf8cd99d5fdf7227af11e20e24);
#
#
#             var icon_39c78655ae23d3a11098a412c1bf4d58 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_466d1ad785642ed1e0925b1fd95c1612 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7ab4b6cd15a7f0234d1518d885f70c1 = $(`&lt;div id=&quot;html_e7ab4b6cd15a7f0234d1518d885f70c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lanzamiento en CCAFS LC-40 - Fallo&lt;/div&gt;`)[0];
#                 popup_466d1ad785642ed1e0925b1fd95c1612.setContent(html_e7ab4b6cd15a7f0234d1518d885f70c1);
#
#
#
#         marker_0f8dde455efc236003e0157744c3ed51.bindPopup(popup_466d1ad785642ed1e0925b1fd95c1612)
#         ;
#
#
#
#
#                 marker_0f8dde455efc236003e0157744c3ed51.setIcon(icon_39c78655ae23d3a11098a412c1bf4d58);
#
#
#             var marker_b642054ea743e95fcb051697d8ef0737 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_c5f64fcf8cd99d5fdf7227af11e20e24);
#
#
#             var icon_b33e18041a77892a3db833e907f8857b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3f99cf52551c2676ffb311c600871ee3 = L.popup({
#   &quot;maxWidth&quot;: &quot;1

# %% [markdown]
# *TODO:* Create a new column in `spacex_df` dataframe called `marker_color` to store the marker colors based on the `class` value

# %%
# Crear la nueva columna 'marker_color' según el valor de 'class'
spacex_df['marker_color'] = spacex_df['class'].apply(lambda x: 'green' if x == 1 else 'red')

# Verificar que los valores han sido asignados correctamente
print(spacex_df[['Launch Site', 'class', 'marker_color']].head())
print(spacex_df[spacex_df['class'] == 1].head())
# Out:
#    Launch Site  class marker_color
# 0  CCAFS LC-40      0          red
# 1  CCAFS LC-40      0          red
# 2  CCAFS LC-40      0          red
# 3  CCAFS LC-40      0          red
# 4  CCAFS LC-40      0          red
#     Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 17             19  2015-06-28   14:21:00   F9 v1.1 B1018  CCAFS LC-40
# 18             20  2015-12-22    1:29:00     F9 FT B1019  CCAFS LC-40
# 20             23  2016-04-08   20:43:00   F9 FT B1021.1  CCAFS LC-40
# 21             24  2016-05-06    5:21:00     F9 FT B1022  CCAFS LC-40
# 22             25  2016-05-27   21:39:00   F9 FT B1023.1  CCAFS LC-40
#
#                                       Payload  Payload Mass (kg)      Orbit  \
# 17                               SpaceX CRS-7             1952.0  LEO (ISS)
# 18  OG2 Mission 2   11 Orbcomm-OG2 satellites             2034.0        LEO
# 20                               SpaceX CRS-8             3136.0  LEO (ISS)
# 21                                   JCSAT-14             4696.0        GTO
# 22                                  Thaicom 8             3100.0        GTO
#
#                   Customer          Landing Outcome  class        Lat  \
# 17              NASA (CRS)  Precluded  (drone ship)      1  28.562302
# 18                 Orbcomm    Success  (ground pad)      1  28.562302
# 20              NASA (CRS)    Success  (drone ship)      1  28.562302
# 21  SKY Perfect JSAT Group     Success (drone ship)      1  28.562302
# 22                 Thaicom    Success  (drone ship)      1  28.562302
#
#          Long marker_color
# 17 -80.577356        green
# 18 -80.577356        green
# 20 -80.577356        green
# 21 -80.577356        green
# 22 -80.577356        green

# %% [markdown]
# *TODO:* For each launch result in `spacex_df` data frame, add a `folium.Marker` to `marker_cluster`

# %%
import folium
from folium.features import DivIcon
from folium.plugins import MarkerCluster
import pandas as pd
from js import fetch
import io

# Descargar y leer el archivo CSV con coordenadas de los sitios de lanzamiento
URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
resp = await fetch(URL)
spacex_csv_file = io.BytesIO((await resp.arrayBuffer()).to_py())
spacex_df = pd.read_csv(spacex_csv_file)

# Filtrar columnas necesarias y eliminar duplicados
launch_sites_df = spacex_df[['Launch Site', 'Lat', 'Long']].drop_duplicates()

# Inicializar el mapa centrado en el Centro Espacial Johnson
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=5, tiles="OpenStreetMap")

# Agregar círculos amarillos y marcadores con texto rojo para cada sitio de lanzamiento
for _, row in launch_sites_df.iterrows():
    folium.Circle(
        location=[row['Lat'], row['Long']],
        radius=1000,
        color='yellow',  # Círculo amarillo para los sitios de lanzamiento
        fill=True,
        fill_color='yellow'
    ).add_child(folium.Popup(row['Launch Site'])).add_to(site_map)

    folium.map.Marker(
        location=[row['Lat'], row['Long']],
        icon=DivIcon(
            icon_size=(20,20),
            icon_anchor=(0,0),
            html='<div style="font-size: 12px; color:red;"><b>%s</b></div>' % row['Launch Site'],  # Texto en rojo
        )
    ).add_to(site_map)

# Crear MarkerCluster para organizar los lanzamientos
marker_cluster = MarkerCluster().add_to(site_map)

# Agregar círculos y marcadores de éxito/fallo en los lanzamientos
for _, row in spacex_df.iterrows():
    color = "green" if row["class"] == 1 else "red"  # Verde para éxito, rojo para fallo

    folium.Circle(
        location=[row["Lat"], row["Long"]],
        radius=500,
        color=color,
        fill=True,
        fill_color=color
    ).add_child(folium.Popup(f"Lanzamiento en {row['Launch Site']} - {'Éxito' if row['class'] == 1 else 'Fallo'}")).add_to(site_map)

    folium.Marker(
        location=[row["Lat"], row["Long"]],
        popup=f"Lanzamiento en {row['Launch Site']} - {'Éxito' if row['class'] == 1 else 'Fallo'}",
        icon=folium.Icon(color=color, icon="rocket")  # Ícono de cohete
    ).add_to(marker_cluster)  # Se agrupan los marcadores en clusters

# Mostrar el mapa en Jupyter Notebook
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af4746ed14da9c4120e5010ed1624a70 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af4746ed14da9c4120e5010ed1624a70&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af4746ed14da9c4120e5010ed1624a70 = L.map(
#                 &quot;map_af4746ed14da9c4120e5010ed1624a70&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_709f8006cc03507303c334226a10ec9c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_709f8006cc03507303c334226a10ec9c.addTo(map_af4746ed14da9c4120e5010ed1624a70);
#
#
#             var circle_d5dba418b78496303949adf0cc8e9b8e = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_af4746ed14da9c4120e5010ed1624a70);
#
#
#         var popup_c9b8795f617b9eb6ce97ed66fb507743 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72a16ca2c2869a07382a8c187d2df18c = $(`&lt;div id=&quot;html_72a16ca2c2869a07382a8c187d2df18c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_c9b8795f617b9eb6ce97ed66fb507743.setContent(html_72a16ca2c2869a07382a8c187d2df18c);
#
#
#
#         circle_d5dba418b78496303949adf0cc8e9b8e.bindPopup(popup_c9b8795f617b9eb6ce97ed66fb507743)
#         ;
#
#
#
#
#             var marker_f37eff35e48a3094b22a8d30c3eba1a5 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_af4746ed14da9c4120e5010ed1624a70);
#
#
#             var div_icon_8e9636ba1cc1e4ab7ff566f6805ad833 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:red;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_f37eff35e48a3094b22a8d30c3eba1a5.setIcon(div_icon_8e9636ba1cc1e4ab7ff566f6805ad833);
#
#
#             var circle_33805bfe86c54386cf86e503bf1f3ac7 = L.circle(
#                 [34.63283416, -120.6107455],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_af4746ed14da9c4120e5010ed1624a70);
#
#
#         var popup_f61ef1828517643c2ecba614bbd262cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8aadab649c5e3bc473fb207eb2dc105 = $(`&lt;div id=&quot;html_a8aadab649c5e3bc473fb207eb2dc105&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC-4E&lt;/div&gt;`)[0];
#                 popup_f61ef1828517643c2ecba614bbd262cf.setContent(html_a8aadab649c5e3bc473fb207eb2dc105);
#
#
#
#         circle_33805bfe86c54386cf86e503bf1f3ac7.bindPopup(popup_f61ef1828517643c2ecba614bbd262cf)
#         ;
#
#
#
#
#             var marker_62ae1735be2256ae99c86a196b3a8d51 = L.marker(
#                 [34.63283416, -120.6107455],
#                 {
# }
#             ).addTo(map_af4746ed14da9c4120e5010ed1624a70);
#
#
#             v

# %% [markdown]
# Your updated map may look like the following screenshots:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster.png">
# </center>

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster_zoomed.png">
# </center>

# %% [markdown]
# From the color-labeled markers in marker clusters, you should be able to easily identify which launch sites have relatively high success rates.

# %%
# TASK 3: Calculate the distances between a launch site to its proximities
import folium
from folium.plugins import MarkerCluster
import pandas as pd
import io
from js import fetch

# Descargar y leer el archivo CSV con coordenadas de los sitios de lanzamiento
URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
resp = await fetch(URL)
spacex_csv_file = io.BytesIO((await resp.arrayBuffer()).to_py())
spacex_df = pd.read_csv(spacex_csv_file)

# Filtrar columnas necesarias y eliminar duplicados
launch_sites_df = spacex_df[['Launch Site', 'Lat', 'Long']].drop_duplicates()

# Contar éxitos y calcular tasas de éxito por sitio de lanzamiento
success_counts = spacex_df.groupby('Launch Site')['class'].sum()
total_counts = spacex_df.groupby('Launch Site')['class'].count()
success_rates = (success_counts / total_counts * 100).round(2)  # Convertir a porcentaje

# Inicializar el mapa centrado en los sitios de lanzamiento
map_center = [launch_sites_df['Lat'].mean(), launch_sites_df['Long'].mean()]
site_map = folium.Map(location=map_center, zoom_start=5)

# Crear `MarkerCluster` para agrupar marcadores
marker_cluster = MarkerCluster().add_to(site_map)

# Agregar marcadores con tasas de éxito en `popup`
for _, row in launch_sites_df.iterrows():
    site_name = row['Launch Site']
    success_rate = success_rates.get(site_name, 0)  # Obtener tasa de éxito

    folium.Marker(
        location=[row["Lat"], row["Long"]],
        popup=f"{site_name}\nTasa de éxito: {success_rate}%",
        icon=folium.Icon(color="blue", icon="info-sign")
    ).add_to(marker_cluster)

# Mostrar el mapa en Jupyter Notebook
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af718a705654a01959e5de0769fea332 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af718a705654a01959e5de0769fea332&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af718a705654a01959e5de0769fea332 = L.map(
#                 &quot;map_af718a705654a01959e5de0769fea332&quot;,
#                 {
#                     center: [30.08289697, -90.60295432500001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_732a346cb67dc3e4525b9872871f0886 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_732a346cb67dc3e4525b9872871f0886.addTo(map_af718a705654a01959e5de0769fea332);
#
#
#             var marker_cluster_2138ea4d30f05320ffbac3c087799ccc = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_a6e8247d78599abb191a7c2c3f07a5f5 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_2138ea4d30f05320ffbac3c087799ccc);
#
#
#             var icon_948a3e46f7dbe6f49f6755728467fe00 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b3e14b1446379801c65a454ce0ff8ac4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_853af2372320c45f351f42bd0e50ae88 = $(`&lt;div id=&quot;html_853af2372320c45f351f42bd0e50ae88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 Tasa de éxito: 26.92%&lt;/div&gt;`)[0];
#                 popup_b3e14b1446379801c65a454ce0ff8ac4.setContent(html_853af2372320c45f351f42bd0e50ae88);
#
#
#
#         marker_a6e8247d78599abb191a7c2c3f07a5f5.bindPopup(popup_b3e14b1446379801c65a454ce0ff8ac4)
#         ;
#
#
#
#
#                 marker_a6e8247d78599abb191a7c2c3f07a5f5.setIcon(icon_948a3e46f7dbe6f49f6755728467fe00);
#
#
#             var marker_d4bf44f88de8e2b051e8458097e969c4 = L.marker(
#                 [34.63283416, -120.6107455],
#                 {
# }
#             ).addTo(marker_cluster_2138ea4d30f05320ffbac3c087799ccc);
#
#
#             var icon_5e130ba999c16d821f0670848c21ec54 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_852189aa71daf1a53b1034030bff719b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cba1678238d2ef039a7ef676009e89e4 = $(`&lt;div id=&quot;html_cba1678238d2ef039a7ef676009e89e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC-4E Tasa de éxito: 40.0%&lt;/div&gt;`)[0];
#                 popup_852189aa71daf1a53b1034030bff719b.setContent(html_cba1678238d2ef039a7ef676009e89e4);
#
#
#
#         marker_d4bf44f88de8e2b051e8458097e969c4.bindPopup(popup_852189aa71daf1a53b1034030bff719b)
#         ;
#
#
#
#
#                 marker_d4bf44f88de8e2b051e8458097e969c4.setIcon(icon_5e130ba999c16d821f0670848c21ec54);
#
#
#             var marker_b438c023e833814b39642642a0a5236b = L.marker(
#                 [28.57325457, -80.64689529],
#                 {
# }
#             ).addTo(marker_cluster_2138ea4d30f05320ffbac3c087799ccc);
#
#
#             var icon_808b955e41afac2b775488b3f52d63df = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3b73afc94a255c2b39d7cfe00752b9d2 = L.popup({
#   &quot;maxWidth&quot;

# %% [markdown]
# Next, we need to explore and analyze the proximities of launch sites.

# %% [markdown]
# Let's first add a `MousePosition` on the map to get coordinate for a mouse over a point on the map. As such, while you are exploring the map, you can easily find the coordinates of any points of interests (such as railway)

# %%
import folium
from folium.plugins import MousePosition, MarkerCluster
from geopy.distance import geodesic
import pandas as pd
import io
from js import fetch

# Descargar y leer el archivo CSV con coordenadas de los sitios de lanzamiento
URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
resp = await fetch(URL)
spacex_csv_file = io.BytesIO((await resp.arrayBuffer()).to_py())
spacex_df = pd.read_csv(spacex_csv_file)

# Filtrar columnas necesarias y eliminar duplicados
launch_sites_df = spacex_df[['Launch Site', 'Lat', 'Long']].drop_duplicates()

# Contar éxitos y calcular tasas de éxito por sitio de lanzamiento
success_counts = spacex_df.groupby('Launch Site')['class'].sum()
total_counts = spacex_df.groupby('Launch Site')['class'].count()
success_rates = (success_counts / total_counts * 100).round(2)  # Convertir a porcentaje

# Inicializar el mapa centrado en los sitios de lanzamiento
map_center = [launch_sites_df['Lat'].mean(), launch_sites_df['Long'].mean()]
site_map = folium.Map(location=map_center, zoom_start=5, tiles="OpenStreetMap")

# Agregar MousePosition para obtener coordenadas dinámicamente al mover el cursor
formatter = "function(lat, lng) {return `Lat: ${lat.toFixed(5)}, Lng: ${lng.toFixed(5)}`;}"
MousePosition(
    position="topright",
    separator=" | ",
    prefix="Coordinates: ",
    latlon=True,
    empty_string="",
    num_digits=5,
    formatter=formatter
).add_to(site_map)

# Crear `MarkerCluster` para agrupar marcadores de lanzamiento
marker_cluster = MarkerCluster().add_to(site_map)

# Agregar sitios de lanzamiento con círculos y nombres
for _, row in launch_sites_df.iterrows():
    site_name = row['Launch Site']
    success_rate = success_rates.get(site_name, 0)  # Obtener tasa de éxito

    # Círculo amarillo para indicar el sitio de lanzamiento
    folium.Circle(
        location=[row['Lat'], row['Long']],
        radius=1000,
        color='yellow',
        fill=True,
        fill_color='yellow'
    ).add_child(folium.Popup(f"{site_name}\nTasa de éxito: {success_rate}%")).add_to(site_map)

    # Marcador con tasa de éxito en el popup
    folium.Marker(
        location=[row["Lat"], row["Long"]],
        popup=f"{site_name}\nTasa de éxito: {success_rate}%",
        icon=folium.Icon(color="blue", icon="info-sign")
    ).add_to(marker_cluster)

# Definir ubicaciones de referencia (aeropuertos, ciudades cercanas, plataformas de recuperación)
ubicaciones_referencia = {
    "Aeropuerto Kennedy": [28.5721, -80.6490],
    "Centro de Recuperación Oceánica": [28.563, -80.571],
    "Ciudad más cercana (Orlando)": [28.5383, -81.3792]
}

# Agregar ubicaciones de referencia con marcadores
for nombre, coord in ubicaciones_referencia.items():
    folium.Marker(
        location=coord,
        popup=nombre,
        icon=folium.Icon(color='red', icon="info-sign")
    ).add_to(site_map)

# Conectar cada sitio de lanzamiento con sus proximidades mediante líneas
for _, row in launch_sites_df.iterrows():
    sitio_coordenadas = [row["Lat"], row["Long"]]
    
    for nombre, coord in ubicaciones_referencia.items():
        distancia = geodesic(sitio_coordenadas, coord).km
        folium.PolyLine(
            [sitio_coordenadas, coord],
            color="red",
            weight=2,
            popup=f"{row['Launch Site']} ➝ {nombre}: {distancia:.2f} km"
        ).add_to(site_map)

# Mostrar el mapa en Jupyter Notebook
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1c655c1dae4f1f910f550711a1ce990 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1c655c1dae4f1f910f550711a1ce990&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1c655c1dae4f1f910f550711a1ce990 = L.map(
#                 &quot;map_b1c655c1dae4f1f910f550711a1ce990&quot;,
#                 {
#                     center: [30.08289697, -90.60295432500001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_597e0fa8f0cfada1443768d935fcb8ce = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_597e0fa8f0cfada1443768d935fcb8ce.addTo(map_b1c655c1dae4f1f910f550711a1ce990);
#
#
#             var mouse_position_d113bf64d21020ca56adbbe2af6c9f9f = new L.Control.MousePosition(
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;separator&quot;: &quot; | &quot;,
#   &quot;emptyString&quot;: &quot;&quot;,
#   &quot;lngFirst&quot;: false,
#   &quot;numDigits&quot;: 5,
#   &quot;prefix&quot;: &quot;Coordinates: &quot;,
#   &quot;latlon&quot;: true,
#   &quot;formatter&quot;: &quot;function(lat, lng) {return `Lat: ${lat.toFixed(5)}, Lng: ${lng.toFixed(5)}`;}&quot;,
# }
#             );
#             mouse_position_d113bf64d21020ca56adbbe2af6c9f9f.options[&quot;latFormatter&quot;] =
#                 undefined;
#             mouse_position_d113bf64d21020ca56adbbe2af6c9f9f.options[&quot;lngFormatter&quot;] =
#                 undefined;
#             map_b1c655c1dae4f1f910f550711a1ce990.addControl(mouse_position_d113bf64d21020ca56adbbe2af6c9f9f);
#
#
#             var marker_cluster_86d075954f62aee0bc0fa2334087a57d = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_2dd12e08298696f69add7da8edb533e7 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_86d075954f62aee0bc0fa2334087a57d);
#
#
#             var icon_274d2821f53ec793820507962dd27b40 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f9ff77329baa50cfa22cf0f412de085f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a12e6180e219b567343d19ac0aa5b11b = $(`&lt;div id=&quot;html_a12e6180e219b567343d19ac0aa5b11b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 Tasa de éxito: 26.92%&lt;/div&gt;`)[0];
#                 popup_f9ff77329baa50cfa22cf0f412de085f.setContent(html_a12e6180e219b567343d19ac0aa5b11b);
#
#
#
#         marker_2dd12e08298696f69add7da8edb533e7.bindPopup(popup_f9ff77329baa50cfa22cf0f412de085f)
#         ;
#
#
#
#
#                 marker_2dd12e08298696f69add7da8edb533e7.setIcon(icon_274d2821f53ec793820507962dd27b40);
#
#
#             var marker_b8025e57a08b8db5e8dc39b7de791952 = L.marker(
#                 [34.63283416, -120.6107455],
#                 {
# }
#             ).addTo(marker_cluster_86d075954f62aee0bc0fa2334087a57d);
#
#
#             var icon_7afc071af76d2af734ddc1b7f08e22ab = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_616e921ada51fa1d8c04375649bf56bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70dbe7719321603455ff94f02e412a93 = $(`&lt;div id=&quot;html_70dbe

# %% [markdown]
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.

# %% [markdown]
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.

# %%
import folium
from folium.plugins import MousePosition, MarkerCluster
from geopy.distance import geodesic
import pandas as pd
import io
from js import fetch
from math import sin, cos, sqrt, atan2, radians

# Función para calcular distancia usando la fórmula de Haversine
def calcular_distancia(lat1, lon1, lat2, lon2):
    R = 6373.0  # Radio de la Tierra en km
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat, dlon = lat2 - lat1, lon2 - lon1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c  # Distancia en km

# Descargar y leer el archivo CSV con sitios de lanzamiento
URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
resp = await fetch(URL)
spacex_csv_file = io.BytesIO((await resp.arrayBuffer()).to_py())
spacex_df = pd.read_csv(spacex_csv_file)

# Filtrar columnas necesarias y eliminar duplicados
launch_sites_df = spacex_df[['Launch Site', 'Lat', 'Long']].drop_duplicates()

# Inicializar el mapa centrado en los sitios de lanzamiento
map_center = [launch_sites_df['Lat'].mean(), launch_sites_df['Long'].mean()]
site_map = folium.Map(location=map_center, zoom_start=5, tiles="OpenStreetMap")

# Agregar funcionalidad MousePosition para obtener coordenadas dinámicamente
formatter = "function(lat, lng) {return `Lat: ${lat.toFixed(5)}, Lng: ${lng.toFixed(5)}`;}"
MousePosition(
    position="topright",
    separator=" | ",
    prefix="Coordenadas: ",
    latlon=True,
    empty_string="",
    num_digits=5,
    formatter=formatter
).add_to(site_map)

# Crear `MarkerCluster` para agrupar marcadores
marker_cluster = MarkerCluster().add_to(site_map)

# Agregar sitios de lanzamiento con círculos y nombres
for _, row in launch_sites_df.iterrows():
    site_name = row['Launch Site']
    folium.Circle(
        location=[row['Lat'], row['Long']],
        radius=1000,
        color='yellow',
        fill=True,
        fill_color='yellow'
    ).add_child(folium.Popup(f"{site_name}")).add_to(site_map)

    folium.Marker(
        location=[row["Lat"], row["Long"]],
        popup=f"{site_name}",
        icon=folium.Icon(color="blue", icon="info-sign")
    ).add_to(marker_cluster)

# Lista de puntos cercanos (ferrocarriles, carreteras, costas) - AGREGAR COORDENADAS MANUALMENTE
puntos_proximos = {
    "Ferrocarril cercano": [28.5728, -80.6500],  # Ejemplo
    "Autopista cercana": [28.5555, -80.5000],    # Ejemplo
    "Costa más cercana": [28.5670, -80.6200]     # Ejemplo
}

# Agregar puntos de referencia en el mapa
for nombre, coord in puntos_proximos.items():
    folium.Marker(
        location=coord,
        popup=nombre,
        icon=folium.Icon(color="red", icon="info-sign")
    ).add_to(site_map)

# Calcular y agregar líneas de distancia entre sitios y puntos de referencia
for _, row in launch_sites_df.iterrows():
    sitio_coordenadas = [row["Lat"], row["Long"]]
    
    for nombre, coord in puntos_proximos.items():
        distancia = calcular_distancia(sitio_coordenadas[0], sitio_coordenadas[1], coord[0], coord[1])
        folium.PolyLine(
            [sitio_coordenadas, coord],
            color="red",
            weight=2,
            popup=f"{row['Launch Site']} ➝ {nombre}: {distancia:.2f} km"
        ).add_to(site_map)

# Mostrar el mapa
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b24e9e624e327c7039736a3ee3bd5d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b24e9e624e327c7039736a3ee3bd5d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b24e9e624e327c7039736a3ee3bd5d7 = L.map(
#                 &quot;map_2b24e9e624e327c7039736a3ee3bd5d7&quot;,
#                 {
#                     center: [30.08289697, -90.60295432500001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6d7fe1a56476e81ace7cdbbc6112a00 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a6d7fe1a56476e81ace7cdbbc6112a00.addTo(map_2b24e9e624e327c7039736a3ee3bd5d7);
#
#
#             var mouse_position_87a06370381dd25714115a9a2cdc5c84 = new L.Control.MousePosition(
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;separator&quot;: &quot; | &quot;,
#   &quot;emptyString&quot;: &quot;&quot;,
#   &quot;lngFirst&quot;: false,
#   &quot;numDigits&quot;: 5,
#   &quot;prefix&quot;: &quot;Coordenadas: &quot;,
#   &quot;latlon&quot;: true,
#   &quot;formatter&quot;: &quot;function(lat, lng) {return `Lat: ${lat.toFixed(5)}, Lng: ${lng.toFixed(5)}`;}&quot;,
# }
#             );
#             mouse_position_87a06370381dd25714115a9a2cdc5c84.options[&quot;latFormatter&quot;] =
#                 undefined;
#             mouse_position_87a06370381dd25714115a9a2cdc5c84.options[&quot;lngFormatter&quot;] =
#                 undefined;
#             map_2b24e9e624e327c7039736a3ee3bd5d7.addControl(mouse_position_87a06370381dd25714115a9a2cdc5c84);
#
#
#             var marker_cluster_04da048aa468975d4e0d401f134a7f9b = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_cc6df62734507cf15d3bb0a176ad4a08 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_04da048aa468975d4e0d401f134a7f9b);
#
#
#             var icon_fec21b500641da40b76dfe378e53d7aa = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_215f2d092a2589905a0f8d9e6fafc502 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f2dd0d680fd60ade61cbccda60eb3e2 = $(`&lt;div id=&quot;html_0f2dd0d680fd60ade61cbccda60eb3e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_215f2d092a2589905a0f8d9e6fafc502.setContent(html_0f2dd0d680fd60ade61cbccda60eb3e2);
#
#
#
#         marker_cc6df62734507cf15d3bb0a176ad4a08.bindPopup(popup_215f2d092a2589905a0f8d9e6fafc502)
#         ;
#
#
#
#
#                 marker_cc6df62734507cf15d3bb0a176ad4a08.setIcon(icon_fec21b500641da40b76dfe378e53d7aa);
#
#
#             var marker_d8517b6d5e6d198a846c94b1d605f1c9 = L.marker(
#                 [34.63283416, -120.6107455],
#                 {
# }
#             ).addTo(marker_cluster_04da048aa468975d4e0d401f134a7f9b);
#
#
#             var icon_a8e576f222d1a915442db78dfc14ebd9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_30075c5152c0c53e4f23f338b6b289f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c66838afdff3456952c4af48cc75ed1 = $(`&lt;div id=&quot;html_7c66838afdff3456952c4af48cc

# %% [markdown]
# *TODO:* Mark down a point on the closest coastline using MousePosition and calculate the distance between the coastline point and the launch site.

# %%
import folium
from folium.plugins import MousePosition
from math import radians, sin, cos, sqrt, atan2

# Función para calcular distancia con la fórmula de Haversine
def calcular_distancia(lat1, lon1, lat2, lon2):
    R = 6373.0  # Radio de la Tierra en km
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat, dlon = lat2 - lat1, lon2 - lon1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

# 🛰 **Coordenadas del sitio de lanzamiento**
launch_site_lat, launch_site_lon = 28.56342, -80.57674  

# 🌊 **Coordenadas de la costa más cercana (ajústalas según MousePosition)**
coastline_lat, coastline_lon = 28.56367, -80.57163  

# 🔎 **Calcular la distancia**
distance_coastline = calcular_distancia(launch_site_lat, launch_site_lon, coastline_lat, coastline_lon)

# 🗺 **Inicializar el mapa**
site_map = folium.Map(location=[launch_site_lat, launch_site_lon], zoom_start=12)

# 📍 **Agregar sitio de lanzamiento**
folium.Marker(
    location=[launch_site_lat, launch_site_lon],
    popup="🚀 Sitio de lanzamiento",
    icon=folium.Icon(color="blue", icon="info-sign")
).add_to(site_map)

# 📍 **Agregar marcador en la costa más cercana**
folium.Marker(
    location=[coastline_lat, coastline_lon],
    popup="🌊 Costa más cercana",
    icon=folium.Icon(color="red", icon="info-sign")
).add_to(site_map)

# 🔗 **Dibujar línea entre los puntos**
folium.PolyLine(
    locations=[[launch_site_lat, launch_site_lon], [coastline_lat, coastline_lon]],
    color="red",
    weight=2,
    tooltip=f"Distancia: {distance_coastline:.2f} km"
).add_to(site_map)

# 🏷 **Etiqueta flotante con la distancia en el mapa**
folium.Marker(
    location=[(launch_site_lat + coastline_lat) / 2, (launch_site_lon + coastline_lon) / 2],  # Posición intermedia
    icon=folium.DivIcon(
        icon_size=(25, 25),
        icon_anchor=(0, 0),
        html=f'<div style="font-size: 14px; color:#d35400;"><b>{distance_coastline:.2f} KM</b></div>'
    )
).add_to(site_map)

# 🛠 **Agregar MousePosition para obtener coordenadas dinámicamente**
formatter = "function(lat, lng) {return `Lat: ${lat.toFixed(5)}, Lng: ${lng.toFixed(5)}`;}"
MousePosition(
    position="topright",
    separator=" | ",
    prefix="Coordenadas: ",
    latlon=True,
    empty_string="",
    num_digits=5,
    formatter=formatter
).add_to(site_map)

# 🌍 **Mostrar el mapa**
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1147fcb53e78972f949538a654dde71f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1147fcb53e78972f949538a654dde71f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1147fcb53e78972f949538a654dde71f = L.map(
#                 &quot;map_1147fcb53e78972f949538a654dde71f&quot;,
#                 {
#                     center: [28.56342, -80.57674],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_12a11d0425d6f72dfda294fd435a83e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_12a11d0425d6f72dfda294fd435a83e1.addTo(map_1147fcb53e78972f949538a654dde71f);
#
#
#             var marker_34d627c7c743764232829293a09414e8 = L.marker(
#                 [28.56342, -80.57674],
#                 {
# }
#             ).addTo(map_1147fcb53e78972f949538a654dde71f);
#
#
#             var icon_fbe8bc5b6ca592a52d0bfd1b68b537b8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e03c12469dc262462cf15e15e35e62a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bfcb9813089358cedff6536561f99b75 = $(`&lt;div id=&quot;html_bfcb9813089358cedff6536561f99b75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;🚀 Sitio de lanzamiento&lt;/div&gt;`)[0];
#                 popup_e03c12469dc262462cf15e15e35e62a8.setContent(html_bfcb9813089358cedff6536561f99b75);
#
#
#
#         marker_34d627c7c743764232829293a09414e8.bindPopup(popup_e03c12469dc262462cf15e15e35e62a8)
#         ;
#
#
#
#
#                 marker_34d627c7c743764232829293a09414e8.setIcon(icon_fbe8bc5b6ca592a52d0bfd1b68b537b8);
#
#
#             var marker_8b4431744eedb53336ac22df46e02b95 = L.marker(
#                 [28.56367, -80.57163],
#                 {
# }
#             ).addTo(map_1147fcb53e78972f949538a654dde71f);
#
#
#             var icon_ea70aaaf0ecfcbc8ccd44648365d34c3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_cdb2440b6c819b541e5dfdc1bc021f6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c53fc0a5a630706997e74e79444b7d3 = $(`&lt;div id=&quot;html_2c53fc0a5a630706997e74e79444b7d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;🌊 Costa más cercana&lt;/div&gt;`)[0];
#                 popup_cdb2440b6c819b541e5dfdc1bc021f6f.setContent(html_2c53fc0a5a630706997e74e79444b7d3);
#
#
#
#         marker_8b4431744eedb53336ac22df46e02b95.bindPopup(popup_cdb2440b6c819b541e5dfdc1bc021f6f)
#         ;
#
#
#
#
#                 marker_8b4431744eedb53336ac22df46e02b95.setIcon(icon_ea70aaaf0ecfcbc8ccd44648365d34c3);
#
#
#             var poly_line_dca90be333e2d19c80d76845329b9a5e = L.polyline(
#                 [[28.56342, -80.57674], [28.56367, -80.57163]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_1147fcb53e78972f949538a654dde71f);
#
#
#             poly_line_dca90be333e2d19c80d76845329b9a5e.bindTooltip(
#                 `&lt;div&gt;
#                      Distancia: 0.50 km
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_5c0e2c477872dd0cb5f425589825f5f4 =

# %%
import folium
from folium.plugins import MousePosition
from math import radians, sin, cos, sqrt, atan2

# Función para calcular distancia con la fórmula de Haversine
def calcular_distancia(lat1, lon1, lat2, lon2):
    R = 6373.0  # Radio de la Tierra en km
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat, dlon = lat2 - lat1, lon2 - lon1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

# 🛰 **Coordenadas del sitio de lanzamiento**
launch_site_lat, launch_site_lon = 28.56342, -80.57674  

# 🌊 **Coordenadas de la costa más cercana (ajústalas según MousePosition)**
coastline_lat, coastline_lon = 28.56367, -80.57163  

# 🔎 **Calcular la distancia**
distance_coastline = calcular_distancia(launch_site_lat, launch_site_lon, coastline_lat, coastline_lon)

# 🗺 **Inicializar el mapa**
site_map = folium.Map(location=[launch_site_lat, launch_site_lon], zoom_start=12)

# 📍 **Agregar sitio de lanzamiento**
folium.Marker(
    location=[launch_site_lat, launch_site_lon],
    popup="🚀 Sitio de lanzamiento",
    icon=folium.Icon(color="blue", icon="info-sign")
).add_to(site_map)

# 📍 **Agregar marcador en la costa más cercana**
folium.Marker(
    location=[coastline_lat, coastline_lon],
    popup="🌊 Costa más cercana",
    icon=folium.Icon(color="red", icon="info-sign")
).add_to(site_map)

# 🔗 **Dibujar línea entre los puntos**
folium.PolyLine(
    locations=[[launch_site_lat, launch_site_lon], [coastline_lat, coastline_lon]],
    color="red",
    weight=2,
    tooltip=f"Distancia: {distance_coastline:.2f} km"
).add_to(site_map)

# 🏷 **Agregar marcador de distancia con DivIcon**
distance_marker = folium.Marker(
    location=[(launch_site_lat + coastline_lat) / 2, (launch_site_lon + coastline_lon) / 2],  # Posición intermedia
    icon=folium.DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12px; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline),
    )
).add_to(site_map)

# 🛠 **Agregar MousePosition para obtener coordenadas dinámicamente**
formatter = "function(lat, lng) {return `Lat: ${lat.toFixed(5)}, Lng: ${lng.toFixed(5)}`;}"
MousePosition(
    position="topright",
    separator=" | ",
    prefix="Coordenadas: ",
    latlon=True,
    empty_string="",
    num_digits=5,
    formatter=formatter
).add_to(site_map)

# 🌍 **Mostrar el mapa**
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0cb8691a5ae4097d69763ab8aa2d8867 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0cb8691a5ae4097d69763ab8aa2d8867&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0cb8691a5ae4097d69763ab8aa2d8867 = L.map(
#                 &quot;map_0cb8691a5ae4097d69763ab8aa2d8867&quot;,
#                 {
#                     center: [28.56342, -80.57674],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a572219efe3c2948553db24b74ef1af = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a572219efe3c2948553db24b74ef1af.addTo(map_0cb8691a5ae4097d69763ab8aa2d8867);
#
#
#             var marker_0f6f20841cb802908744be1506db16f6 = L.marker(
#                 [28.56342, -80.57674],
#                 {
# }
#             ).addTo(map_0cb8691a5ae4097d69763ab8aa2d8867);
#
#
#             var icon_cf77789a868a29e2bec5c7ea12e12a24 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6d367c0f9d98b84dc41d9bdd8ea20846 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d9df8c80c4ae4380ec79a3c0d3fb62e = $(`&lt;div id=&quot;html_5d9df8c80c4ae4380ec79a3c0d3fb62e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;🚀 Sitio de lanzamiento&lt;/div&gt;`)[0];
#                 popup_6d367c0f9d98b84dc41d9bdd8ea20846.setContent(html_5d9df8c80c4ae4380ec79a3c0d3fb62e);
#
#
#
#         marker_0f6f20841cb802908744be1506db16f6.bindPopup(popup_6d367c0f9d98b84dc41d9bdd8ea20846)
#         ;
#
#
#
#
#                 marker_0f6f20841cb802908744be1506db16f6.setIcon(icon_cf77789a868a29e2bec5c7ea12e12a24);
#
#
#             var marker_c548e35791cc959c7c2446c3e36f1e44 = L.marker(
#                 [28.56367, -80.57163],
#                 {
# }
#             ).addTo(map_0cb8691a5ae4097d69763ab8aa2d8867);
#
#
#             var icon_cb77592cbfffd18aecbd7cc9c96e370b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_26cba9336c42cacd6ae5c78295a45596 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3addb57cccb11c59847b0c3f67296e88 = $(`&lt;div id=&quot;html_3addb57cccb11c59847b0c3f67296e88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;🌊 Costa más cercana&lt;/div&gt;`)[0];
#                 popup_26cba9336c42cacd6ae5c78295a45596.setContent(html_3addb57cccb11c59847b0c3f67296e88);
#
#
#
#         marker_c548e35791cc959c7c2446c3e36f1e44.bindPopup(popup_26cba9336c42cacd6ae5c78295a45596)
#         ;
#
#
#
#
#                 marker_c548e35791cc959c7c2446c3e36f1e44.setIcon(icon_cb77592cbfffd18aecbd7cc9c96e370b);
#
#
#             var poly_line_af683fb5f106e23a2fff18d562a5013d = L.polyline(
#                 [[28.56342, -80.57674], [28.56367, -80.57163]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_0cb8691a5ae4097d69763ab8aa2d8867);
#
#
#             poly_line_af683fb5f106e23a2fff18d562a5013d.bindTooltip(
#                 `&lt;div&gt;
#                      Distancia: 0.50 km
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_8c37158aa7d908fac1cf6538d15d79b2 =

# %% [markdown]
# *TODO:* Draw a `PolyLine` between a launch site to the selected coastline point

# %%
import folium
from folium.plugins import MousePosition
from math import radians, sin, cos, sqrt, atan2

# Función para calcular distancia con la fórmula de Haversine
def calcular_distancia(lat1, lon1, lat2, lon2):
    R = 6373.0  # Radio de la Tierra en km
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat, dlon = lat2 - lat1, lon2 - lon1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

# 🛰 **Coordenadas del sitio de lanzamiento**
launch_site_lat, launch_site_lon = 28.56342, -80.57674  

# 🌊 **Coordenadas de la costa más cercana (ajústalas según MousePosition)**
coastline_lat, coastline_lon = 28.56367, -80.57163  

# 🔎 **Calcular la distancia**
distance_coastline = calcular_distancia(launch_site_lat, launch_site_lon, coastline_lat, coastline_lon)

# 🗺 **Inicializar el mapa**
site_map = folium.Map(location=[launch_site_lat, launch_site_lon], zoom_start=12)

# 📍 **Agregar sitio de lanzamiento**
folium.Marker(
    location=[launch_site_lat, launch_site_lon],
    popup="🚀 Sitio de lanzamiento",
    icon=folium.Icon(color="blue", icon="info-sign")
).add_to(site_map)

# 📍 **Agregar marcador en la costa más cercana**
folium.Marker(
    location=[coastline_lat, coastline_lon],
    popup="🌊 Costa más cercana",
    icon=folium.Icon(color="red", icon="info-sign")
).add_to(site_map)

# 🔗 **Dibujar línea entre los puntos con `PolyLine`**
lines = folium.PolyLine(
    locations=[[launch_site_lat, launch_site_lon], [coastline_lat, coastline_lon]],
    color="red",
    weight=2,
    tooltip=f"Distancia: {distance_coastline:.2f} km"
)
site_map.add_child(lines)

# 🏷 **Agregar marcador de distancia con etiqueta flotante**
folium.Marker(
    location=[(launch_site_lat + coastline_lat) / 2, (launch_site_lon + coastline_lon) / 2],  # Posición intermedia
    icon=folium.DivIcon(
        icon_size=(25,25),
        icon_anchor=(0,0),
        html=f'<div style="font-size: 14px; color:#d35400;"><b>{distance_coastline:.2f} KM</b></div>'
    )
).add_to(site_map)

# 🛠 **Agregar MousePosition para obtener coordenadas dinámicamente**
formatter = "function(lat, lng) {return `Lat: ${lat.toFixed(5)}, Lng: ${lng.toFixed(5)}`;}"
MousePosition(
    position="topright",
    separator=" | ",
    prefix="Coordenadas: ",
    latlon=True,
    empty_string="",
    num_digits=5,
    formatter=formatter
).add_to(site_map)

# 🌍 **Mostrar el mapa**
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfe3237c565c2eb028ac6991780f7faf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfe3237c565c2eb028ac6991780f7faf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfe3237c565c2eb028ac6991780f7faf = L.map(
#                 &quot;map_cfe3237c565c2eb028ac6991780f7faf&quot;,
#                 {
#                     center: [28.56342, -80.57674],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f13ad68b0e100260cb50175ec3efb496 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f13ad68b0e100260cb50175ec3efb496.addTo(map_cfe3237c565c2eb028ac6991780f7faf);
#
#
#             var marker_389d6727c390a000fb23e76cb172e798 = L.marker(
#                 [28.56342, -80.57674],
#                 {
# }
#             ).addTo(map_cfe3237c565c2eb028ac6991780f7faf);
#
#
#             var icon_b743c0b20be611e5939b5c3ca4236522 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8b4470ebdbc120d048d9aa54d2b7c74e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_470d31c05fb25f59667a555f55b42b93 = $(`&lt;div id=&quot;html_470d31c05fb25f59667a555f55b42b93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;🚀 Sitio de lanzamiento&lt;/div&gt;`)[0];
#                 popup_8b4470ebdbc120d048d9aa54d2b7c74e.setContent(html_470d31c05fb25f59667a555f55b42b93);
#
#
#
#         marker_389d6727c390a000fb23e76cb172e798.bindPopup(popup_8b4470ebdbc120d048d9aa54d2b7c74e)
#         ;
#
#
#
#
#                 marker_389d6727c390a000fb23e76cb172e798.setIcon(icon_b743c0b20be611e5939b5c3ca4236522);
#
#
#             var marker_da169ee855ed9c776fc5fcc8ccf4ad60 = L.marker(
#                 [28.56367, -80.57163],
#                 {
# }
#             ).addTo(map_cfe3237c565c2eb028ac6991780f7faf);
#
#
#             var icon_09490f39a2aa65745d9a9122c996ed82 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f4de6a79c6bb3c651bac2a71a340cccf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96bae891632ebb0e942198129c7802f9 = $(`&lt;div id=&quot;html_96bae891632ebb0e942198129c7802f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;🌊 Costa más cercana&lt;/div&gt;`)[0];
#                 popup_f4de6a79c6bb3c651bac2a71a340cccf.setContent(html_96bae891632ebb0e942198129c7802f9);
#
#
#
#         marker_da169ee855ed9c776fc5fcc8ccf4ad60.bindPopup(popup_f4de6a79c6bb3c651bac2a71a340cccf)
#         ;
#
#
#
#
#                 marker_da169ee855ed9c776fc5fcc8ccf4ad60.setIcon(icon_09490f39a2aa65745d9a9122c996ed82);
#
#
#             var poly_line_fb404edf6cc2b6558c84bcc6935c0554 = L.polyline(
#                 [[28.56342, -80.57674], [28.56367, -80.57163]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_cfe3237c565c2eb028ac6991780f7faf);
#
#
#             poly_line_fb404edf6cc2b6558c84bcc6935c0554.bindTooltip(
#                 `&lt;div&gt;
#                      Distancia: 0.50 km
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_0e075a6bb5d7b8b87356c6857d61ef6f =

# %% [markdown]
# Your updated map with distance line should look like the following screenshot:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_distance.png">
# </center>

# %% [markdown]
# *TODO:* Similarly, you can draw a line betwee a launch site to its closest city, railway, highway, etc. You need to use `MousePosition` to find the their coordinates on the map first

# %% [markdown]
# A railway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/railway.png">
# </center>

# %% [markdown]
# A highway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/highway.png">
# </center>

# %% [markdown]
# A city map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/city.png">
# </center>

# %%
# Create a marker with distance to a closest city, railway, highway, etc.
# Draw a line between the marker to the launch site
import folium
from math import radians, sin, cos, sqrt, atan2

# Función para calcular distancia con Haversine
def calcular_distancia(lat1, lon1, lat2, lon2):
    R = 6373.0  # Radio de la Tierra en km
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat, dlon = lat2 - lat1, lon2 - lon1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

# 🛰 **Coordenadas del sitio de lanzamiento**
launch_site_lat, launch_site_lon = 28.56342, -80.57674  

# 🏙 **Ubicaciones de referencia cercanas**
ubicaciones_cercanas = {
    "Ciudad más cercana (Orlando)": [28.5383, -81.3792],
    "Ferrocarril cercano": [28.5728, -80.6500],
    "Autopista cercana": [28.5555, -80.5000]
}

# 🗺 **Inicializar el mapa**
site_map = folium.Map(location=[launch_site_lat, launch_site_lon], zoom_start=10)

# 📍 **Agregar marcador en el sitio de lanzamiento**
folium.Marker(
    location=[launch_site_lat, launch_site_lon],
    popup=" Sitio de lanzamiento",
    icon=folium.Icon(color="blue", icon="info-sign")
).add_to(site_map)

#  **Agregar marcadores de ubicaciones cercanas y líneas de conexión**
for nombre, coord in ubicaciones_cercanas.items():
    distancia = calcular_distancia(launch_site_lat, launch_site_lon, coord[0], coord[1])
    
    # Agregar marcador
    folium.Marker(
        location=coord,
        popup=f"{nombre}",
        icon=folium.Icon(color="red", icon="info-sign")
    ).add_to(site_map)

    # Dibujar línea entre la ubicación y el sitio de lanzamiento
    folium.PolyLine(
        locations=[[launch_site_lat, launch_site_lon], coord],
        color="red",
        weight=2,
        tooltip=f"Distancia a {nombre}: {distancia:.2f} km"
    ).add_to(site_map)

    # 🏷 **Agregar etiqueta flotante con la distancia**
    folium.Marker(
        location=[(launch_site_lat + coord[0]) / 2, (launch_site_lon + coord[1]) / 2],  # Punto intermedio
        icon=folium.DivIcon(
            icon_size=(25,25),
            icon_anchor=(0,0),
            html=f'<div style="font-size: 14px; color:#d35400;"><b>{distancia:.2f} KM</b></div>'
        )
    ).add_to(site_map)

# 🌍 **Mostrar el mapa**
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c80b16f3c6ff692bcf800105b5c4bd89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c80b16f3c6ff692bcf800105b5c4bd89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c80b16f3c6ff692bcf800105b5c4bd89 = L.map(
#                 &quot;map_c80b16f3c6ff692bcf800105b5c4bd89&quot;,
#                 {
#                     center: [28.56342, -80.57674],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5bb2f76f580966060612f7f2c44717bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5bb2f76f580966060612f7f2c44717bf.addTo(map_c80b16f3c6ff692bcf800105b5c4bd89);
#
#
#             var marker_b4a1ade2bc5d32bd2f46e9d125f43113 = L.marker(
#                 [28.56342, -80.57674],
#                 {
# }
#             ).addTo(map_c80b16f3c6ff692bcf800105b5c4bd89);
#
#
#             var icon_b3c5fb6657d42ea8af72d1e1fe8519eb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_372551628178fd493f477ba274b4c923 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a3429fa3fdb151490d4e41beb3e8aa0 = $(`&lt;div id=&quot;html_7a3429fa3fdb151490d4e41beb3e8aa0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;🚀 Sitio de lanzamiento&lt;/div&gt;`)[0];
#                 popup_372551628178fd493f477ba274b4c923.setContent(html_7a3429fa3fdb151490d4e41beb3e8aa0);
#
#
#
#         marker_b4a1ade2bc5d32bd2f46e9d125f43113.bindPopup(popup_372551628178fd493f477ba274b4c923)
#         ;
#
#
#
#
#                 marker_b4a1ade2bc5d32bd2f46e9d125f43113.setIcon(icon_b3c5fb6657d42ea8af72d1e1fe8519eb);
#
#
#             var marker_3c81334b1d3163e7dddb4af1c10c5c8d = L.marker(
#                 [28.5383, -81.3792],
#                 {
# }
#             ).addTo(map_c80b16f3c6ff692bcf800105b5c4bd89);
#
#
#             var icon_ec2b036d7ba79f0cd5a126a07e67f61e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_dfbc9e8361f3db2cf27c6ecc2c9ca6be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_817c1420abcd95d9cbeab809150a01a2 = $(`&lt;div id=&quot;html_817c1420abcd95d9cbeab809150a01a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ciudad más cercana (Orlando)&lt;/div&gt;`)[0];
#                 popup_dfbc9e8361f3db2cf27c6ecc2c9ca6be.setContent(html_817c1420abcd95d9cbeab809150a01a2);
#
#
#
#         marker_3c81334b1d3163e7dddb4af1c10c5c8d.bindPopup(popup_dfbc9e8361f3db2cf27c6ecc2c9ca6be)
#         ;
#
#
#
#
#                 marker_3c81334b1d3163e7dddb4af1c10c5c8d.setIcon(icon_ec2b036d7ba79f0cd5a126a07e67f61e);
#
#
#             var poly_line_784f248e0a1f2aa23abcc10cbf2915ba = L.polyline(
#                 [[28.56342, -80.57674], [28.5383, -81.3792]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_c80b16f3c6ff692bcf800105b5c4bd89);
#
#
#             poly_line_784f248e0a1f2aa23abcc10cbf2915ba.bindTooltip(
#                 `&lt;div&gt;
#                      Distancia a Ciudad más cercana (Orlando): 78.45 km
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_2e795eec5aea93fb58595a6758e93ff7 = L.marker(
#                 [28.55086, -80.97797],
#                 {
# }
#             ).addTo(map_c80b16f3c6ff692bcf800105b5c4bd89);
#
#
#             var div_icon_7f3ddba5f4bd156ece694ba606ec9220 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\

# %% [markdown]
# After you plot distance lines to the proximities, you can answer the following questions easily:
#
# *   Are launch sites in close proximity to railways?
# *   Are launch sites in close proximity to highways?
# *   Are launch sites in close proximity to coastline?
# *   Do launch sites keep certain distance away from cities?
#
# Also please try to explain your findings.

# %% [markdown]
# # Next Steps:
#
# Now you have discovered many interesting insights related to the launch sites' location using folium, in a very interactive way. Next, you will need to build a dashboard using Ploty Dash on detailed launch records.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Pratiksha Verma](https://www.linkedin.com/in/pratiksha-verma-6487561b1/)

# %% [markdown]
# <!--## Change Log--!>

# %% [markdown]
# <!--| Date (YYYY-MM-DD) | Version | Changed By      | Change Description      |
# | ----------------- | ------- | -------------   | ----------------------- |
# | 2022-11-09        | 1.0     | Pratiksha Verma | Converted initial version to Jupyterlite|--!>

# %% [markdown]
# ### <h3 align="center"> IBM Corporation 2022. All rights reserved. <h3/>
